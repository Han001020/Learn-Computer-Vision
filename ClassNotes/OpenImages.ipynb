# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread("../DATA/wii.jpg")

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img_gray = cv2.imread("../DATA/wii.jpg",cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_rgb.shape
# Out:
# (506, 650, 3)

# %%
img_resize = cv2.resize(img_rgb,(400,200))

# %%
plt.imshow(img_resize)

# %%
ratio = 0.1

# %%
new_img = cv2.resize(img_rgb,(0,0),img_rgb,ratio,ratio)

# %%
plt.imshow(new_img)
