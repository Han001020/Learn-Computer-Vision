# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('MYDATA/wii.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (506, 650, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_arr)

# %%
pic_red.shape
# Out:
# (506, 650, 3)

# %%
# R G B

# RED CHANNELVALUES 0-255
plt.imshow(pic_red[:,:,0], cmap='gray')

# %%
plt.imshow(pic_red[:,:,1], cmap='gray')

# %%
plt.imshow(pic_red[:,:,2], cmap='gray')

# %%
#GREEN CHANNEL
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)
